# %% [markdown]
# # Machine Learning
# ---
#   Machine Learning is a field of AI where computers learn patterns from data instead of being explicitly programmed.
# ---
# ### Types of machine learning
# - supervised
#     - Regression
#     - classification
# - unsupervised
#     - clusturing
#     - dimensnionality reduction
#     - Anamoly detection
#     - association
# - semisupervised
# - reinforcement

# %% [markdown]
# # Types of machine learning based on learning
# ### instance vs model based learning
# #### instance
#         - memorizing i.e Ratta
#         - similarity based on distance
#         - Algorithm KNN
#         - No as such concept of training and learning in instance based learning
# #### model base
#         - generalizing i.e following patteren | extract underline principle
#         - learn behavior from data by drawing a mathematical function
#         - it draw a boundry
#         - learn and train from data
#         - most of the algorithm use this approach
#         - find mathematical relationship b/w input and output

# %% [markdown]
# # key differences

# %% [markdown]
# # Usual/Conventional Machine Learning | model based learning
#
# Prepare the data for model training
#
# Train model from training data to estimate model parameters i.e. discover patterns
#
# Store the model in suitable form
#
# Generalize the rules in form of model. even before scoring instance is seen
#
# Predict for unseen scoring instance using model
#
# Can throw away input/training data after model training
#
# Requires a known model form
#
# Storing models generally requires less storage
#
# # Instance Based Learning
#
# No differences here Prepare the data for model training
#
# Do not train model. Pattern discovery postponed until scoring query received
#
# There is no model to store
#
# No generalization before scoring. Only
#
# generalize for each scoring instance individually as and when seen
#
# Predict for unseen scoring instance using training data directly
#
# Input/training data must be kept since each query uses part or full set of training observations
#
# May not have explicit model form
#
# Storing training data generally requires more storage

# %% [markdown]
# # challenges in machine learning

# %% [markdown]
# ## collection of data
#     -API
#     -Web scraping

# %% [markdown]
# ## insufficient data/ labeled data
# -if u have huge amount of data then algorithm does not matter  but as more data is not easily available so that is why algorithm  matters

# %% [markdown]
# ## no representaitve data
# -mean u have some data and later data is increased
#     -sampling noise
#     - sampling bias

# %% [markdown]
# ## Poor quality data
#     -missing values
#     -data in different format

# %% [markdown]
# ## irrelevent features/columns
#
# ## overfitting
#     -Ratta and memorized things
#     -i.e if price  of one thing in peshawar is highy and i say that every thing in peshawar is very highy/costly
#
# ## under fitting
#  -opposite of overfitting
#
# ## software integration
#
# ## offline learning/ deployment
#  -offline => not constantly updating
#
#
# ## cost involved
#  ---

# %% [markdown]
# # MLDLC (Machine learning Development lifecycle)
#
# ### 1.Frame the problem
#     - identify problem
#     - identify customer
#     - Total cost
#     - how will end product look like
#     - model to implement is supervised or unsupervised
#     - offline mode or batch mode
#     - from where the data will data will come
#
# ### 2.Gathering Data
#     - Directly from csv file
#     - API
#     - Web scrapping
#     - databases
#     - spark/cluster
#
# ### 3.Data Preprocessing
#     - remove duplicates
#     - remove missing values
#     - outliers
#     - scale
#
# ### 4.Exploratory data analysis (EDA)
#     -To understand what is in data
#     -extract relationship
#     -doing experiments
#     -visulization (Ploting graphs)
#         -univariate analysis(independent analysis on every column i.e identify mean, std etc)
#         - bivariate(analyze two columns to understand the relationship)
#         - outlier detection
#         - imbalance to balance dataset
#
# ### 5.Feature Engineering and selection
#     - feature -> input columns
#     - creating new columns
#     -create new features
#     - change existing features
#     - select important columns
#
# ### 6.model training and evaluation
#     - train different models
#     - evaluation i.e through performance matrix, accuracy score mean score
#
#
#
# ### 7.model deployment
#
#
# ### 8.Testing
#     -Beta testing
#
#
# ### 9. Optimize
# ---
