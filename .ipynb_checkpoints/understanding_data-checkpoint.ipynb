# %%
import pandas as pd

# %%
#Asking basic questions
#what are the basic question that u ask when u first get data

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 1. How big is the data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 2. How does the data look like?

# %%
df.head()
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 171          172         0       3        Rice, Master. Arthur    male   4.0
# 836          837         0       3            Pasic, Mr. Jakob    male  21.0
# 547          548         1       2  Padro y Manent, Mr. Julian    male   NaN
# 792          793         0       3     Sage, Miss. Stella Anna  female   NaN
# 817          818         0       2          Mallet, Mr. Albert    male  31.0
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked
# 171      4      1           382652  29.1250   NaN        Q
# 836      0      0           315097   8.6625   NaN        S
# 547      0      0    SC/PARIS 2146  13.8625   NaN        C
# 792      8      2         CA. 2343  69.5500   NaN        S
# 817      1      1  S.C./PARIS 2079  37.0042   NaN        C

# %% [markdown]
#  ### 3. what is the datatype of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 4. Are there any missing values

# %%
 df.isnull().sum() #it will show how many missing values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 5. How does the data look mathematically?

# %%
df.describe() #only numerical values insights
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 6. Are there duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  ### 7. How is the correlation between cols?
#      identify relation between columns or data
#      to remove unnecessiry columns

# %%
df.corr(numeric_only=True)['Survived'] #Survived realtion -> Survive relation with 'Fare' is high 
#and with 'Pclass' very negetive relation (pclass in a train is inexpensive so the suvival % is less)
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
