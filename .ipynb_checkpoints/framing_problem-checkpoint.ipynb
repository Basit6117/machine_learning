# %% [markdown]
# ### Bussiness Problem To ML Problem

# %% [markdown]
# To increase churn rate (Netflix)
#     -convert it to mathematical problem i.e from 4% to 3.75%
#     - what will be the end product -> big picture
#     -identify those customers who leaving platform
#     - immediate action to give theme discount next month
#     - supervised -> regression

# %% [markdown]
# ## Current solution
#     -existing solultion i.e a system that tell the overall churn rate prediction so u can start from there not necessirily from scratch

# %% [markdown]
# ### Geting Data
#     -watch time
#     -search but did not find
#     -content left in the middle
#     -clicked on recomendations(order of recomendation)
#
#
# so we need data engineer to give data from netflix database to DW (data wearhouse)

# %% [markdown]
# ### Matrics to measure
#     -identify is your model successfull or not

# %% [markdown]
# ### online vs batch

# %%
import pandas as pd

# A valid CSV URL from a public GitHub repo
url = "https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Titanic.csv"  # Titanic dataset :contentReference[oaicite:0]{index=0}

df = pd.read_csv(url)

print(df.head())
print(df.shape)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
import pandas as pd

# A valid CSV URL from a public GitHub repo
url = "https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Titanic.csv"  # Titanic dataset :contentReference[oaicite:0]{index=0}

df = pd.read_csv(url)

print(df.head())
print(df.shape)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...
